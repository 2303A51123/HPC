# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51123/HPC/blob/main/Ass_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import time

N = 10_000_000

A = np.arange(N, dtype=np.float64)
B = np.arange(N, dtype=np.float64)

# Scalar loop
C = np.zeros(N)
start = time.time()
for i in range(N):
    C[i] = A[i] + B[i]
end = time.time()
print("Normal loop time:", end - start)

# Vectorized (SIMD-like)
start = time.time()
C = A + B
end = time.time()
print("Vectorized time:", end - start)
# Out:
# Normal loop time: 7.126668214797974
# Vectorized time: 0.07000255584716797

# %%
import numpy as np
import time

N = 10_000_000
A = np.ones(N, dtype=np.float64)

# Normal loop
start = time.time()
s = 0.0
for i in range(N):
    s += A[i]
end = time.time()
print("Normal sum:", s, "Time:", end - start)

# Vectorized reduction
start = time.time()
s = np.sum(A)
end = time.time()
print("Vectorized sum:", s, "Time:", end - start)
# Out:
# Normal sum: 10000000.0 Time: 3.6253793239593506
# Vectorized sum: 10000000.0 Time: 0.01327371597290039

# %%
import numpy as np
import time

N = 10_000_000

unaligned = np.arange(N + 1, dtype=np.float64)[1:]
aligned = np.arange(N, dtype=np.float64)

start = time.time()
np.sum(unaligned)
print("Unaligned time:", time.time() - start)

start = time.time()
np.sum(aligned)
print("Aligned time:", time.time() - start)
# Out:
# Unaligned time: 0.010653018951416016
# Aligned time: 0.010424613952636719

# %%
import numpy as np
import time

N = 10_000_000
A = np.arange(N, dtype=np.float64)

start = time.time()
B = A * 2.0
print("Vectorized (SIMD + multithreaded) time:", time.time() - start)
# Out:
# Vectorized (SIMD + multithreaded) time: 0.04751849174499512

# %%
import numpy as np
import time

N = 10_000_000
A = np.random.rand(N) * 100
B = np.zeros(N)

start = time.time()
for i in range(N):
    if A[i] > 50:
        B[i] = A[i] * 2
    else:
        B[i] = A[i] / 2
print("Branch loop time:", time.time() - start)
# Out:
# Branch loop time: 7.3477866649627686

# %%
start = time.time()
B = np.where(A > 50, A * 2, A / 2)
print("Vectorized conditional time:", time.time() - start)
# Out:
# Vectorized conditional time: 0.223191499710083
